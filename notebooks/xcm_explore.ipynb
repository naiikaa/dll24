# %%
from datasets import load_dataset

dataset = load_dataset('DBD-research-group/BirdSet','XCM')

# %%
import matplotlib.pyplot as plt
import soundfile as sf
import numpy as np


ax = plt.figure(figsize=(20,20)).add_subplot(projection='3d')
for i in range(0,20):
    data, sr = sf.read(dataset['test_5s'][i]['filepath'])
    ax.plot(np.arange(0,len(data)),data,zs=i,zdir='y')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 8
#       6 ax = plt.figure(figsize=(20,20)).add_subplot(projection='3d')
#       7 for i in range(0,20):
# ----> 8     data, sr = sf.read(dataset['test_5s'][i]['filepath'])
#       9     ax.plot(np.arange(0,len(data)),data,zs=i,zdir='y')
#
# File ~/.local/lib/python3.10/site-packages/datasets/dataset_dict.py:75, in DatasetDict.__getitem__(self, k)
#      73 def __getitem__(self, k) -> Dataset:
#      74     if isinstance(k, (str, NamedSplit)) or len(self) == 0:
# ---> 75         return super().__getitem__(k)
#      76     else:
#      77         available_suggested_splits = [
#      78             split for split in (Split.TRAIN, Split.TEST, Split.VALIDATION) if split in self
#      79         ]
#
# KeyError: 'test_5s'
